# %% [markdown]
# # **NLP classique**

# %% [markdown]
# # Chargement des corpus

# %% [markdown]
# ## Noms des produits : corpus `product_name`

# %%
from flipkart_utils import get_raw_data, full_show_sample
corpus = get_raw_data('product_name')
display(corpus.shape)
full_show_sample(corpus, print_func=print)
# Out:
# (1050,)
# ('f01140c02fd09e5c56312a64fa8db3da', 'Cookart Elegant S.S. Handi With Hot Pot Pack of 4 Casserole Set')
# ('78fcb634d9838127464d827234ab05ad', 'Happiness Is Printed Bone China Mug')
# ('07912328f580cf080d721e6466287896', 'Wallmantra Abstract Colors Modern Art Wall Hanging Canvas Painting')
# ('5eec66ec172ce096cd4e5c947686b56a', "RTD Baby Girl's Kurta and Pyjama Set")
# ('af13232271963742c118a1c58affa259', 'Adaa Sitting Nandi with Round Base Showpiece  -  4 cm')

# %% [markdown]
# ## Descriptions des produits : corpus `description`

# %%
from flipkart_utils import get_raw_data, full_show_sample
corpus = get_raw_data('description')
display(corpus.shape)
full_show_sample(corpus, print_func=print)
# Out:
# (1050,)
# ('9e90fb6c7870637b6f794e4b4c26bd7e', 'Feetje Trousers - Buy Blue Feetje Trousers For Only Rs. 399 Online in India. Shop Online For Apparels. Huge Collection of Branded Clothes Only at Flipkart.com')
# ('95330f6f0f44d17b918feec36bedcdef', 'Specifications of RYTHMX FB NAIL POLISHES BLACK LIPSTICKS IMPORTANT COMBO 47 (Set of 4) Combo Set Details Number of Contents in Combo Set 4 Combo Set Contents 2 Nail polish, 2 LIPSTICKS Organic Yes Ideal For Women General Traits Professional Care Yes Warranty After use Lipsticks No Exchange / No Return')
# ('8a184fe2c82ba6a17fbe07f94d0dd875', "Specifications of chota packet Baby Boy's, Baby Girl's Bodysuit General Details Sleeve Half sleeves Bootie No Closure Button Age Group 0 -  18 month Number of Contents in Sales Package Pack of 1 Fabric Cotton Pattern Solid Ideal For Baby Boy's, Baby Girl's Hood No Fabric Care Normal Wash, Do not iron on print")
# ...

# %% [markdown]
# # Division en phrases

# %% [markdown]
# ## Noms des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import ravel_corpus_sents
corpus = get_raw_data('product_name')
corpus_sents = ravel_corpus_sents(corpus)
display(corpus_sents)
# Out:
#                                     id sent_id  \
# 0     55b85ea15a1536d46b7190ad6fff8ce7       0
# 1     7b72c92c2f6c40268628ec5f14c6d590       0
# 2     64d5d4a258243731dc7bbb1eef49ad74       0
# 3     d4684dcdc759dd9cdf41504698d737d8       0
# 4     6325b6870c54cd47be6ebfbffa620ec7       0
# ...                                ...     ...
# 1055  958f54f4c46b53c8a0a9b8167d9140bc       0
# 1056  fd6cbcc22efb6b761bd564c28928483c       0
# 1057  5912e037d12774bb73a2048f35a00009       0
# 1058  c3edc504d1b4f0ba6224fa53a43a7ad6       0
# 1059  f2f027ad6a6df617c9f125173da71e44       0
#
#                                            product_name
# 0     Elegance Polyester Multicolor Abstract Eyelet ...
# 1                            Sathiyas Cotton Bath Towel
# 2                   Eurospa Cotton Terry Face Towel Set
# 3     SANTOSH ROYAL FASHION Cotton Printed King size...
# 4     Jaipur Print Cotton Floral King sized Double B...
# ...                                                 ...
# ...

# %% [markdown]
# ## Descriptions des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import ravel_corpus_sents
corpus = get_raw_data('description')
corpus_sents = ravel_corpus_sents(corpus)
display(corpus_sents)
# Out:
#                                     id sent_id  \
# 0     55b85ea15a1536d46b7190ad6fff8ce7       0
# 1     55b85ea15a1536d46b7190ad6fff8ce7       1
# 2     55b85ea15a1536d46b7190ad6fff8ce7       2
# 3     55b85ea15a1536d46b7190ad6fff8ce7       3
# 4     55b85ea15a1536d46b7190ad6fff8ce7       4
# ...                                ...     ...
# 5194  c3edc504d1b4f0ba6224fa53a43a7ad6       3
# 5195  f2f027ad6a6df617c9f125173da71e44       0
# 5196  f2f027ad6a6df617c9f125173da71e44       1
# 5197  f2f027ad6a6df617c9f125173da71e44       2
# 5198  f2f027ad6a6df617c9f125173da71e44       3
#
#                                             description
# 0     Key Features of Elegance Polyester Multicolor ...
# 1     899 This curtain enhances the look of the inte...
# 2        The surreal attention is sure to steal hearts.
# 3     These contemporary eyelet and valance curtains...
# 4     Bring home the elegant curtain that softly fil...
# ...                                                 ...
# ...

# %% [markdown]
# # Prétraitements

# %% [markdown]
# ## Casefolding
#
# C'est la première opération normalisante à effectuer.

# %% [markdown]
# ### Noms des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import ravel_corpus_sents, corpus_casefold
corpus = get_raw_data('product_name')
corpus_sents = ravel_corpus_sents(corpus)
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
display(sents)
# Out:
# 0       elegance polyester multicolor abstract eyelet ...
# 1                              sathiyas cotton bath towel
# 2                     eurospa cotton terry face towel set
# 3       santosh royal fashion cotton printed king size...
# 4       jaipur print cotton floral king sized double b...
#                               ...
# 1055       oren empower extra large self adhesive sticker
# 1056               wallmantra large vinyl sticker sticker
# 1057    uberlyfe extra large pigmented polyvinyl films...
# 1058              wallmantra medium vinyl sticker sticker
# 1059                         uberlyfe large vinyl sticker
# Name: product_name, Length: 1060, dtype: object

# %% [markdown]
# ### Descriptions des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import ravel_corpus_sents, corpus_casefold
corpus = get_raw_data('description')
corpus_sents = ravel_corpus_sents(corpus)
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
display(sents)
# Out:
# 0       key features of elegance polyester multicolor ...
# 1       899 this curtain enhances the look of the inte...
# 2          the surreal attention is sure to steal hearts.
# 3       these contemporary eyelet and valance curtains...
# 4       bring home the elegant curtain that softly fil...
#                               ...
# 5194                        30 day replacement guarantee.
# 5195    buy uberlyfe large vinyl sticker for rs.595 on...
# 5196    uberlyfe large vinyl sticker at best prices wi...
# 5197                               only genuine products.
# 5198                        30 day replacement guarantee.
# Name: description, Length: 5199, dtype: object

# %% [markdown]
# ## Remplacement (ou élimination) de certains symboles

# %%
"""from tx_ml import load
from tx_prep import ravel_corpus_sents, corpus_casefold, corpus_replace_symbols
corpus = load('Tweets.csv').text
corpus_sents = ravel_corpus_sents(corpus)
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
sents = corpus_replace_symbols(sents, "+-/#@", " ")
display(sents)"""
# Out:
# 0                        virginamerica what dhepburn said
# 1         virginamerica plus you've added commercials t...
# 2         virginamerica i didn't today must mean i need...
# 3         virginamerica it's really aggressive to blast...
# 4         virginamerica and it's a really big bad thing...
#                                ...
# 29378     americanair you have my money you change my f...
# 29379    any other suggestions so i can make my commitm...
# 29380                                                    ?
# 29381     americanair we have 8 ppl so we need 2 know h...
# 29382    plz put us on standby for 4 people on the next...
# Name: text, Length: 29383, dtype: object

# %% [markdown]
# ## Décomposition des phrases en listes de mots

# %% [markdown]
# ### Noms des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import ravel_corpus_sents, corpus_casefold, word_tokenize_corpus
corpus_sents = ravel_corpus_sents(get_raw_data('product_name'))
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
# sents = corpus_replace_symbols(sents, "+-/#@", " ")
tokenized_sents = word_tokenize_corpus(sents)
display(tokenized_sents)
# Out:
# 0       [elegance, polyester, multicolor, abstract, ey...
# 1                         [sathiyas, cotton, bath, towel]
# 2              [eurospa, cotton, terry, face, towel, set]
# 3       [santosh, royal, fashion, cotton, printed, kin...
# 4       [jaipur, print, cotton, floral, king, sized, d...
#                               ...
# 1055    [oren, empower, extra, large, self, adhesive, ...
# 1056         [wallmantra, large, vinyl, sticker, sticker]
# 1057    [uberlyfe, extra, large, pigmented, polyvinyl,...
# 1058        [wallmantra, medium, vinyl, sticker, sticker]
# 1059                    [uberlyfe, large, vinyl, sticker]
# Name: product_name, Length: 1060, dtype: object

# %% [markdown]
# ### Descriptions des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import ravel_corpus_sents, corpus_casefold, word_tokenize_corpus
corpus_sents = ravel_corpus_sents(get_raw_data('description'))
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
# sents = corpus_replace_symbols(sents, "+-/#@", " ")
tokenized_sents = word_tokenize_corpus(sents)
display(tokenized_sents)
# Out:
# 0       [key, features, of, elegance, polyester, multi...
# 1       [899, this, curtain, enhances, the, look, of, ...
# 2       [the, surreal, attention, is, sure, to, steal,...
# 3       [these, contemporary, eyelet, and, valance, cu...
# 4       [bring, home, the, elegant, curtain, that, sof...
#                               ...
# 5194                 [30, day, replacement, guarantee, .]
# 5195    [buy, uberlyfe, large, vinyl, sticker, for, rs...
# 5196    [uberlyfe, large, vinyl, sticker, at, best, pr...
# 5197                         [only, genuine, products, .]
# 5198                 [30, day, replacement, guarantee, .]
# Name: description, Length: 5199, dtype: object

# %% [markdown]
# ## Filtrage des mots sans intérêt
#
# Stopwords, ponctuation, mots en dehors d'un intervalle de taille, mots contenant un pattern particulier.

# %% [markdown]
# ### Noms des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import ravel_corpus_sents, corpus_casefold, word_tokenize_corpus, filter_product_names
corpus_sents = ravel_corpus_sents(get_raw_data('product_name'))
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
# sents = corpus_replace_symbols(sents, "+-/#@", " ")
tokenized_sents = word_tokenize_corpus(sents)
filtered_tokenized_sents = tokenized_sents.apply(filter_product_names)
display(filtered_tokenized_sents)
# Out:
# 0       [elegance, polyester, multicolor, abstract, ey...
# 1                         [sathiyas, cotton, bath, towel]
# 2              [eurospa, cotton, terry, face, towel, set]
# 3       [santosh, royal, fashion, cotton, printed, kin...
# 4       [jaipur, print, cotton, floral, king, sized, d...
#                               ...
# 1055    [oren, empower, extra, large, self, adhesive, ...
# 1056         [wallmantra, large, vinyl, sticker, sticker]
# 1057    [uberlyfe, extra, large, pigmented, polyvinyl,...
# 1058        [wallmantra, medium, vinyl, sticker, sticker]
# 1059                    [uberlyfe, large, vinyl, sticker]
# Name: product_name, Length: 1060, dtype: object

# %% [markdown]
# ### Descriptions des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import ravel_corpus_sents, corpus_casefold, word_tokenize_corpus, filter_product_descriptions
corpus_sents = ravel_corpus_sents(get_raw_data('description'))
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
# sents = corpus_replace_symbols(sents, "+-/#@", " ")
tokenized_sents = word_tokenize_corpus(sents)
filtered_tokenized_sents = tokenized_sents.apply(filter_product_descriptions)
display(filtered_tokenized_sents)
# Out:
# 0       [key, features, elegance, polyester, multicolo...
# 1       [899, curtain, enhances, look, curtain, made, ...
# 2               [surreal, attention, sure, steal, hearts]
# 3       [contemporary, eyelet, valance, curtains, slid...
# 4       [bring, home, elegant, curtain, softly, filter...
#                               ...
# 5194                        [day, replacement, guarantee]
# 5195       [buy, uberlyfe, large, vinyl, sticker, online]
# 5196    [uberlyfe, large, vinyl, sticker, best, prices...
# 5197                                  [genuine, products]
# 5198                        [day, replacement, guarantee]
# Name: description, Length: 5199, dtype: object

# %% [markdown]
# ## Lemmatisation
#
# Abstraction du mot en le remplaçant par son représentant de lexème.
#
# C'est la dernière étape (nous n'abordons pas l'analyse sémantique) avant de reformer les phrases comme chaînes.

# %% [markdown]
# ### Noms des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import (
    ravel_corpus_sents,
    corpus_casefold,
    # corpus_replace_symbols,
    word_tokenize_corpus,
    filter_product_names,
    lemmatize_words
)
corpus_sents = ravel_corpus_sents(get_raw_data('product_name'))
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
# sents = corpus_replace_symbols(sents, "+-/#@", " ")
sents = word_tokenize_corpus(sents)
sents = sents.apply(filter_product_names)
sents = sents.apply(lemmatize_words)
display(sents)
# Out:
# 0       [elegance, polyester, multicolor, abstract, ey...
# 1                         [sathiyas, cotton, bath, towel]
# 2              [eurospa, cotton, terry, face, towel, set]
# 3       [santosh, royal, fashion, cotton, printed, kin...
# 4       [jaipur, print, cotton, floral, king, sized, d...
#                               ...
# 1055    [oren, empower, extra, large, self, adhesive, ...
# 1056         [wallmantra, large, vinyl, sticker, sticker]
# 1057    [uberlyfe, extra, large, pigmented, polyvinyl,...
# 1058        [wallmantra, medium, vinyl, sticker, sticker]
# 1059                    [uberlyfe, large, vinyl, sticker]
# Name: product_name, Length: 1060, dtype: object

# %% [markdown]
# ### Descriptions des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import (
    ravel_corpus_sents,
    corpus_casefold,
    # corpus_replace_symbols,
    word_tokenize_corpus,
    filter_product_descriptions,
    lemmatize_words
)
corpus_sents = ravel_corpus_sents(get_raw_data('description'))
sents = corpus_sents[corpus_sents.columns[-1]]
sents = corpus_casefold(sents)
# sents = corpus_replace_symbols(sents, "+-/#@", " ")
sents = word_tokenize_corpus(sents)
sents = sents.apply(filter_product_descriptions)
sents = sents.apply(lemmatize_words)
display(sents)
# Out:
# 0       [key, feature, elegance, polyester, multicolor...
# 1       [899, curtain, enhances, look, curtain, made, ...
# 2                [surreal, attention, sure, steal, heart]
# 3       [contemporary, eyelet, valance, curtain, slide...
# 4       [bring, home, elegant, curtain, softly, filter...
#                               ...
# 5194                        [day, replacement, guarantee]
# 5195       [buy, uberlyfe, large, vinyl, sticker, online]
# 5196    [uberlyfe, large, vinyl, sticker, best, price,...
# 5197                                   [genuine, product]
# 5198                        [day, replacement, guarantee]
# Name: description, Length: 5199, dtype: object

# %% [markdown]
# ## Tout en un, avec `join` final

# %% [markdown]
# ### Noms des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import preprocess_corpus, filter_product_names
sents, sents_index = preprocess_corpus(
    corpus=get_raw_data('product_name'),
    discard_words_function=filter_product_names,
    sent_tokenize=True,
)
display(sents)
display(sents_index)
# Out:
# 0       elegance polyester multicolor abstract eyelet ...
# 1                              sathiyas cotton bath towel
# 2                     eurospa cotton terry face towel set
# 3       santosh royal fashion cotton printed king size...
# 4       jaipur print cotton floral king sized double b...
#                               ...
# 1055       oren empower extra large self adhesive sticker
# 1056               wallmantra large vinyl sticker sticker
# 1057    uberlyfe extra large pigmented polyvinyl film ...
# 1058              wallmantra medium vinyl sticker sticker
# 1059                         uberlyfe large vinyl sticker
# Name: product_name, Length: 1060, dtype: object
#                                     id sent_id
# 0     55b85ea15a1536d46b7190ad6fff8ce7       0
# 1     7b72c92c2f6c40268628ec5f14c6d590       0
# 2     64d5d4a258243731dc7bbb1eef49ad74       0
# 3     d4684dcdc759dd9cdf41504698d737d8       0
# 4     6325b6870c54cd47be6ebfbffa620ec7       0
# ...

# %% [markdown]
# ### Descriptions des produits

# %%
from flipkart_utils import get_raw_data
from tx_prep import preprocess_corpus, filter_product_descriptions
sents, sents_index = preprocess_corpus(
    corpus=get_raw_data('description'),
    discard_words_function=filter_product_descriptions,
    sent_tokenize=True,
)
display(sents)
display(sents_index)
# Out:
# 0       key feature elegance polyester multicolor abst...
# 1       899 curtain enhances look curtain made 100 hig...
# 2                      surreal attention sure steal heart
# 3       contemporary eyelet valance curtain slide smoo...
# 4       bring home elegant curtain softly filter light...
#                               ...
# 5194                            day replacement guarantee
# 5195              buy uberlyfe large vinyl sticker online
# 5196    uberlyfe large vinyl sticker best price free s...
# 5197                                      genuine product
# 5198                            day replacement guarantee
# Name: description, Length: 5199, dtype: object
#                                     id sent_id
# 0     55b85ea15a1536d46b7190ad6fff8ce7       0
# 1     55b85ea15a1536d46b7190ad6fff8ce7       1
# 2     55b85ea15a1536d46b7190ad6fff8ce7       2
# 3     55b85ea15a1536d46b7190ad6fff8ce7       3
# 4     55b85ea15a1536d46b7190ad6fff8ce7       4
# ...

# %% [markdown]
# # Sampling
#
# Echantillonnage stratifié.
#
# Fonction ad hoc puis revenir sur CVFolds.

# %% [markdown]
# ## Rappel de la distribution / classes

# %%
from flipkart_utils import (
    get_class_labels,
    get_class_names,
    get_class_label_name_map
)
import pandas as pd

cla_labels = get_class_labels()
cla_names = get_class_names()
cla_names_map = get_class_label_name_map()

display(cla_names_map)

vc = pd.concat([
    cla_names.value_counts().rename('#'),
    cla_names.value_counts(normalize=True).rename('%')
], axis=1)
display(vc)
# Out:
# {0: 'Baby Care',
#  1: 'Beauty and Personal Care',
#  2: 'Computers',
#  3: 'Home Decor & Festive Needs',
#  4: 'Home Furnishing',
#  5: 'Kitchen & Dining',
#  6: 'Watches'}
#                               #         %
# Home Furnishing             150  0.142857
# Baby Care                   150  0.142857
# Watches                     150  0.142857
# Home Decor & Festive Needs  150  0.142857
# Kitchen & Dining            150  0.142857
# Beauty and Personal Care    150  0.142857
# Computers                   150  0.142857

# %% [markdown]
# ## Echantillon stratifié

# %%
from flipkart_utils import (
    get_class_labels,
    get_class_names,
    get_class_label_name_map
)

from tx_ml import stratified_sample

cla_labels = get_class_labels()
cla_names = get_class_names()
display(get_class_label_name_map())

sample = stratified_sample(cla_labels, size=.5)
display(sample.value_counts().reset_index()[["cla"]].T)
# Out:
# {0: 'Baby Care',
#  1: 'Beauty and Personal Care',
#  2: 'Computers',
#  3: 'Home Decor & Festive Needs',
#  4: 'Home Furnishing',
#  5: 'Kitchen & Dining',
#  6: 'Watches'}
#       0   1   2   3   4   5   6
# cla  75  75  75  75  75  75  75

# %% [markdown]
# # Bag of word (Count, Tfidf)

# %%
from flipkart_utils import get_raw_data
from tx_prep import preprocess_corpus, filter_product_names
from tx_ml import get_sents_class_labels

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

sents, _ = preprocess_corpus(
    corpus=get_raw_data('product_name'),
    discard_words_function=filter_product_names
)

cla_labels = get_sents_class_labels(sents_index, get_class_labels())

# TODO : c'est ici que je devrais échantillonner. puis distinguer le fit et le transform

c_vectorizer = CountVectorizer(stop_words='english', max_df=0.95, min_df=1)
f_vectorizer = TfidfVectorizer(stop_words='english', max_df=0.95, min_df=1)

c_sents = c_vectorizer.fit_transform(sents)
f_sents = f_vectorizer.fit_transform(sents)

# %% [markdown]
# ## Exécution des modèles

# %%
from pepper_utils import print_subtitle
from tx_ml import tsne_kmeans_ari
print_subtitle("CountVectorizer")
c_X_tsne, c_clu_labels, c_ari, _, _  = tsne_kmeans_ari(c_sents, cla_labels, verbosity=2)
print_subtitle("TfidfVectorizer")
f_X_tsne, f_clu_labels, f_ari, _, _  = tsne_kmeans_ari(f_sents, cla_labels, verbosity=2)
# Out:
# CountVectorizer
# T-SNE time: 5.69s
# KMeans time: 0.47s
# ARI time: 0.00s
# Total time : 6.16s
#
# ARI : 0.3157
#
# TfidfVectorizer
# T-SNE time: 5.61s
# KMeans time: 0.42s
# ARI time: 0.00s
# Total time : 6.03s
#
# ARI : 0.3579

# %% [markdown]
# ## Graphiques

# %%
from tx_ml import show_tsne
from flipkart_utils import get_class_label_name_map
cla_names = list(get_class_label_name_map().values())
show_tsne(
    cla_labels, cla_names, c_X_tsne, c_clu_labels,
    {"c_ari": round(c_ari, 2)},
    {
        "corpus": {"name": "product_name"},
        "extractor": {"name": "CountVectorizer"},
        "kmeans": {},
        "tsne": {}
    }
)

# %%
from tx_ml import show_tsne
from flipkart_utils import get_class_label_name_map
cla_names = list(get_class_label_name_map().values())
show_tsne(
    cla_labels, cla_names, f_X_tsne, f_clu_labels,
    {"f_ari": round(f_ari, 2)},
    {
        "corpus": {"name": "product_name"},
        "extractor": {"name": "TfidfVectorizer"},
        "kmeans": {},
        "tsne": {}
    }
)

# %%
from scoring import show_confusion_matrix, display_classification_report

show_confusion_matrix(cla_labels, c_clu_labels)
display_classification_report(cla_labels, c_clu_labels)
# Out:
# Confusion matrix
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.58      0.70       150
#            1       0.48      0.43      0.45       150
#            2       0.27      0.45      0.33       150
#            3       0.56      0.66      0.61       150
#            4       0.30      0.27      0.28       150
#            5       0.76      0.49      0.60       150
#            6       1.00      0.99      1.00       150
#
#     accuracy                           0.55      1050
#    macro avg       0.60      0.55      0.57      1050
# weighted avg       0.60      0.55      0.57      1050

# %%
from scoring import show_confusion_matrix, display_classification_report

show_confusion_matrix(cla_labels, f_clu_labels)
display_classification_report(cla_labels, f_clu_labels)
# Out:
# Confusion matrix
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.68      0.55      0.61       150
#            1       0.48      0.47      0.47       150
#            2       0.72      0.57      0.63       150
#            3       0.32      0.50      0.39       150
#            4       0.67      0.68      0.67       150
#            5       0.66      0.50      0.57       150
#            6       0.91      0.99      0.95       150
#
#     accuracy                           0.61      1050
#    macro avg       0.63      0.61      0.61      1050
# weighted avg       0.63      0.61      0.61      1050

# %% [markdown]
# # Word2Vec
#
# ARI : 0.3
#
# Les deux fonctions suivantes concernent la construction d'un modèle d'embedding en utilisant le modèle Word2Vec et le tokenizer Keras. La première fonction `get_embedding_matrix` sert à créer la matrice d'embedding en utilisant le modèle Word2Vec et le tokenizer Keras. Le but est de convertir chaque mot en vecteur à partir du modèle Word2Vec, et de stocker ces vecteurs dans une matrice. La matrice aura la forme `(vocab_size, w2v_size)`, où `vocab_size` est la taille du vocabulaire du tokenizer Keras et `w2v_size` est la dimension du modèle Word2Vec.
#
# La seconde fonction `get_embeddeding_model` sert à construire un modèle Keras qui prend en entrée des phrases tokenizées et renvoie les vecteurs d'embedding associés. Elle crée un modèle Keras avec une entrée de forme `(nombre de phrases, longueur maximale de la phrase)` et renvoie un vecteur d'embedding de longueur `w2v_size` pour chaque phrase. Les poids pré-entraînés de la matrice d'embedding sont attachés à la couche d'embedding du modèle.

# %% [markdown]
# ## Création du modèle Word2Vec

# %%
from flipkart_utils import get_raw_data
from tx_prep import preprocess_corpus, filter_product_names
from tx_ml import get_sents_class_labels

sents, sents_index = preprocess_corpus(
    corpus=get_raw_data('product_name'),
    discard_words_function=filter_product_names
)
cla_labels = get_sents_class_labels(sents_index, get_class_labels())

# %% [markdown]
# Globals

# %%
w2v_size = 300
w2v_window = 5
w2v_min_count = 1
w2v_epochs = 100
maxlen = 24 # adapt to length of sentences

# %% [markdown]
# List of lists of Gesim preprocessed words

# %%
from tx_ml import gesim_simple_preprocess
_sents = gesim_simple_preprocess(sents)
print(_sents[:5])
# Out:
# [['elegance', 'polyester', 'multicolor', 'abstract', 'eyelet', 'door', 'curtain'], ['sathiyas', 'cotton', 'bath', 'towel'], ['eurospa', 'cotton', 'terry', 'face', 'towel', 'set'], ['santosh', 'royal', 'fashion', 'cotton', 'printed', 'king', 'sized', 'double', 'bedsheet'], ['jaipur', 'print', 'cotton', 'floral', 'king', 'sized', 'double', 'bedsheet']]

# %%
from tx_ml import fit_word2vec
w2v_model = fit_word2vec(_sents)
# Out:
# Build & train Word2Vec model ...
# Vocabulary size: 1800
# Word2Vec trained

# %%
model_vectors = w2v_model.wv
print(f"model_vectors ({len(model_vectors)}", model_vectors)
w2v_words = model_vectors.index_to_key
print(f"w2v_words ({len(w2v_words)})", w2v_words[:10])
print("watch vector", model_vectors['watch'][:50])
# Out:
# model_vectors (1800 KeyedVectors<vector_size=300, 1800 keys>
# w2v_words (1800) ['watch', 'set', 'analog', 'showpiece', 'baby', 'combo', 'ceramic', 'men', 'mug', 'girl']
# watch vector [-0.410461    0.34080374 -0.01075173 -0.45465404  0.04452817  0.12422159
#   0.17115225 -0.069916   -0.1992241   0.6173883   0.526991    0.35278684
#   0.56116873  0.67643565  0.24930927 -0.28997168 -0.12536775 -0.6336723
#  -0.5178318  -0.3132102   0.28675097  0.31899944 -0.381672    0.879197
#   0.5761318   0.15343139 -1.0988574   0.38286617 -0.32635346 -0.17500739
#  -0.11021139 -0.5247165   0.31830207  0.09785517  0.4682864   0.29445356
#   0.3426943  -0.5896202  -0.17500043  0.14349115  0.22428018  1.084483
#   0.49581635  0.53041095 -0.21856879  0.6507846   0.4217629   0.94832206
#   0.80959207  0.9078926 ]

# %%
from tx_ml import fit_keras_tokenizer
keras_tokenizer, x_sents = fit_keras_tokenizer(_sents)
display(keras_tokenizer)
print(x_sents.shape)
display(x_sents)
# Out:
# Fit Tokenizer ...
# Number of unique words: 1801
# (1050, 24)
# array([[419,  42,  23, ...,   0,   0,   0],
#        [681,  13,  49, ...,   0,   0,   0],
#        [682,  13, 420, ...,   0,   0,   0],
#        ...,
#        [680, 418, 199, ...,   0,   0,   0],
#        [175, 158, 174, ...,   0,   0,   0],
#        [680, 199, 174, ...,   0,   0,   0]])

# %% [markdown]
# ## Création de la matrice d'embedding

# %%
from tx_ml import get_embedding_matrix
embedding_matrix = get_embedding_matrix(w2v_model, keras_tokenizer)
# Out:
# Create Embedding matrix ...
# Word embedding rate :  1.0
# Embedding matrix:  (1801, 300)

# %% [markdown]
# ## Création du modèle d'embedding

# %%
from tx_ml import get_embedding_model
keras_model = get_embedding_model(x_sents, w2v_model, keras_tokenizer, embedding_matrix)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 24)]              0
#
#  embedding (Embedding)       (None, 24, 300)           540300
#
#  global_average_pooling1d (G  (None, 300)              0
#  lobalAveragePooling1D)
#
# ...
# Total params: 540,300
# Trainable params: 540,300
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Exécution du modèle

# %%
embeddings = keras_model.predict(x_sents)
embeddings.shape
# Out:
# 33/33 [==============================] - 1s 2ms/step
# (1050, 300)

# %%
from tx_ml import tsne_kmeans_ari
wve_X_tsne, wve_clu_labels, wve_ari, _, _ = tsne_kmeans_ari(embeddings, cla_labels, verbosity=2)
# Out:
# T-SNE time: 4.65s
# KMeans time: 0.36s
# ARI time: 0.00s
# Total time : 5.01s
#
# ARI : 0.4879

# %%
from tx_ml import show_tsne
from flipkart_utils import get_class_label_name_map
cla_names = list(get_class_label_name_map().values())
show_tsne(
    cla_labels, cla_names, wve_X_tsne, wve_clu_labels,
    {"wve_ari": round(wve_ari, 2)},
    {
        "corpus": {"name": "product_name"},
        "extractor": {"name": "Keras_Word2Vec"},
        "kmeans": {},
        "tsne": {}
    }
)

# %%
from scoring import show_confusion_matrix, display_classification_report

show_confusion_matrix(cla_labels, wve_clu_labels)
display_classification_report(cla_labels, wve_clu_labels)
# Out:
# Confusion matrix
# Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.54      0.70       150
#            1       0.45      0.60      0.52       150
#            2       0.29      0.41      0.34       150
#            3       0.76      0.77      0.77       150
#            4       0.81      0.92      0.86       150
#            5       0.95      0.49      0.64       150
#            6       0.98      1.00      0.99       150
#
#     accuracy                           0.68      1050
#    macro avg       0.75      0.68      0.69      1050
# weighted avg       0.75      0.68      0.69      1050

# %% [markdown]
# # BERT
#
# ARI : 0.5

# %%
from flipkart_utils import get_raw_data
from tx_prep import preprocess_corpus, filter_product_names
from tx_ml import get_sents_class_labels

sents, sents_index = preprocess_corpus(
    corpus=get_raw_data('product_name'),
    discard_words_function=filter_product_names
)
cla_labels = get_sents_class_labels(sents_index, get_class_labels())

# %%
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
n_gpu = len(tf.config.experimental.list_physical_devices('GPU'))
print("Num GPUs Available:", n_gpu)
print("Built with cuda:", tf.test.is_built_with_cuda())
# Out:
# Tensorflow version: 2.11.0
# Num GPUs Available: 0
# Built with cuda: False

# %% [markdown]
# ## BERT HuggingFace

# %% [markdown]
# ### 'bert-base-uncased'

# %%
from transformers import TFAutoModel
max_length = 64
batch_size = 10
model_type = 'bert-base-uncased'
model = TFAutoModel.from_pretrained(model_type)
# Out:
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
# Création des features
from tx_ml import extract_bert_sentence_embeddings
bert_features, _ = extract_bert_sentence_embeddings(
    model,
    model_type,
    sents, 
    max_length,
    batch_size,
    mode='HF'
)
# Out:
# 105/105 [==============================] - 85s 740ms/step

# %%
from tx_ml import tsne_kmeans_ari
bert_X_tsne, bert_clu_labels, bert_ari, _, _ = tsne_kmeans_ari(bert_features, cla_labels, verbosity=2)
# Out:
# T-SNE time: 4.71s
# KMeans time: 0.37s
# ARI time: 0.00s
# Total time : 5.08s
#
# ARI : 0.5574

# %%
from tx_ml import show_tsne
from flipkart_utils import get_class_label_name_map
cla_names = list(get_class_label_name_map().values())
show_tsne(
    cla_labels, cla_names, bert_X_tsne, bert_clu_labels,
    {"bert_ari": round(bert_ari, 2)},
    {
        "corpus": {"name": "product_name"},
        "extractor": {"name": "bert-base-uncased"},
        "kmeans": {},
        "tsne": {}
    }
)

# %%
from scoring import show_confusion_matrix, display_classification_report

show_confusion_matrix(cla_labels, bert_clu_labels)
display_classification_report(cla_labels, bert_clu_labels)
# Out:
# Confusion matrix
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.73      0.60      0.66       150
#            1       0.69      0.71      0.70       150
#            2       0.92      0.81      0.87       150
#            3       0.70      0.69      0.69       150
#            4       0.82      0.92      0.87       150
#            5       0.68      0.65      0.66       150
#            6       0.82      0.99      0.90       150
#
#     accuracy                           0.77      1050
#    macro avg       0.77      0.77      0.76      1050
# weighted avg       0.77      0.77      0.76      1050

# %% [markdown]
# # USE - Universal Sentence Encoder
#
# ARI : 0.6

# %%
from flipkart_utils import get_raw_data
from tx_prep import preprocess_corpus, filter_product_names
from tx_ml import get_sents_class_labels

sents, sents_index = preprocess_corpus(
    corpus=get_raw_data('product_name'),
    discard_words_function=filter_product_names
)

cla_labels = get_sents_class_labels(sents_index, get_class_labels())

# %%
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
n_gpu = len(tf.config.experimental.list_physical_devices('GPU'))
print("Num GPUs Available:", n_gpu)
print("Built with cuda:", tf.test.is_built_with_cuda())
# Out:
# Tensorflow version: 2.11.0
# Num GPUs Available: 0
# Built with cuda: False

# %%
# Création des features
from tx_ml import extract_use_sentence_embeddings
use_features = extract_use_sentence_embeddings(sents)
# Out:
# USE time: 30.28s

# %%
from tx_ml import tsne_kmeans_ari
use_X_tsne, use_clu_labels, use_ari, _, _ = tsne_kmeans_ari(use_features, cla_labels, verbosity=2)
# Out:
# T-SNE time: 4.70s
# KMeans time: 0.46s
# ARI time: 0.02s
# Total time : 5.18s
#
# ARI : 0.6139

# %%
from tx_ml import show_tsne
from flipkart_utils import get_class_label_name_map
cla_names = list(get_class_label_name_map().values())
show_tsne(
    cla_labels, cla_names, use_X_tsne, use_clu_labels,
    {"use_ari": round(use_ari, 2)},
    {
        "corpus": {"name": "product_name"},
        "extractor": {"name": "USE"},
        "kmeans": {},
        "tsne": {}
    }
)

# %%
from scoring import show_confusion_matrix, display_classification_report

show_confusion_matrix(cla_labels, use_clu_labels)
display_classification_report(cla_labels, use_clu_labels)
# Out:
# Confusion matrix
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.62      0.76       150
#            1       0.94      0.80      0.87       150
#            2       0.87      0.87      0.87       150
#            3       0.43      0.37      0.40       150
#            4       0.80      0.99      0.89       150
#            5       0.54      0.74      0.63       150
#            6       0.96      1.00      0.98       150
#
#     accuracy                           0.77      1050
#    macro avg       0.79      0.77      0.77      1050
# weighted avg       0.79      0.77      0.77      1050
