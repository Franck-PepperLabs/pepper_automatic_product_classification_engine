# %% [markdown]
# # **NLP Pipeline**
#
# Le but de ce notebook et d'enchaîner la séquences des transformations distribuées sur plusieurs sections dans les autres notebooks, qui ont vocation de support de présentation.
#
# La motivation principale a été de pouvoir multiplier les configurations testées sans devoir remonter toutes les chaînes, en particulier de tester les différentes méthodes d'analyse factorielle proposées par Scikit-learn.
#
# Ici, l'exécution est complète et complètement déterminée par un configuration donnée en entrée.

# %% [markdown]
# # Pipeline (OLD RECYCL)

# %% [markdown]
# ## Description produits avec `word_tokenizer` NLTK

# %%
from tx_pipeline import *
name = 'description'
sents, cla_labels = tx_ml_preprocess(name)
tx_ml_bow_count(sents, cla_labels, name)
tx_ml_bow_tfidf(sents, cla_labels, name)
tx_ml_word2vec(sents, cla_labels, name)
tx_ml_bert(sents, cla_labels, name)
tx_ml_use(sents, cla_labels, name)
# Out:
# TEXT PREPROCESSING (DESCRIPTION)
#
# BAG OF WORDS - COUNTVECTORIZER (DESCRIPTION)
#
# Feature extraction
#
# tSNE and ARI
# T-SNE time: 59.46s
# KMeans time: 1.19s
# ARI time: 0.00s
# Total time : 60.65s
#
# ARI : 0.0707
#
# Plot
# ARI :  0.07071580370366788
#
# BAG OF WORDS - TFIDFVECTORIZER (DESCRIPTION)
#
# Feature extraction
#
# tSNE and ARI
# T-SNE time: 57.82s
# KMeans time: 0.86s
# ARI time: 0.00s
# Total time : 58.68s
#
# ARI : 0.055
#
# Plots
# ARI :  0.05496931393867186
#
# EMBEDDING - WORD2VEC (DESCRIPTION)
#
# Assemblage et entraînement du modèle
# ...

# %% [markdown]
# ## Description produits avec `flipkart_word_tokenize` NLTK

# %%
from pipeline import *
from tx_prep import flipkart_word_tokenize
name = 'description'
sents, cla_labels = tx_ml_preprocess(name, flipkart_word_tokenize)
tx_ml_bow_count(sents, cla_labels, name)
tx_ml_bow_tfidf(sents, cla_labels, name)
tx_ml_word2vec(sents, cla_labels, name)
tx_ml_bert(sents, cla_labels, name)
tx_ml_use(sents, cla_labels, name)
# Out:
# TEXT PREPROCESSING (DESCRIPTION)
#
# BAG OF WORDS - COUNTVECTORIZER (DESCRIPTION)
#
# Feature extraction
#
# tSNE and ARI
# T-SNE time: 71.68s
# KMeans time: 1.06s
# ARI time: 0.00s
# Total time : 72.73s
#
# ARI : 0.0856
#
# Plot
# ARI :  0.08563313990066217
#
# BAG OF WORDS - TFIDFVECTORIZER (DESCRIPTION)
#
# Feature extraction
#
# tSNE and ARI
# T-SNE time: 65.26s
# KMeans time: 0.82s
# ARI time: 0.00s
# Total time : 66.08s
#
# ARI : 0.0348
#
# Plots
# ARI :  0.034775930646845074
#
# EMBEDDING - WORD2VEC (DESCRIPTION)
#
# Assemblage et entraînement du modèle
# ...

# %%
from flipkart_utils import (
    get_raw_data,
    get_class_labels,
    get_class_label_name_map
)

from tx_prep import (
    flipkart_word_tokenize,
    preprocess_corpus,
    filter_product_names,
    filter_product_descriptions
)

name = 'description'
sents, sents_index = preprocess_corpus(
    corpus=get_raw_data(name),
    tokenize_func=flipkart_word_tokenize,
    discard_words_function=filter_product_descriptions
)
display(sents)
# Out:
# 0       key feature elegance polyester multicolor abst...
# 1       curtain enhances look curtain made high qualit...
# 2                      surreal attention sure steal heart
# 3       contemporary eyelet valance curtain slide smoo...
# 4       bring home elegant curtain softly filter light...
#                               ...
# 5194                            day replacement guarantee
# 5195              buy uberlyfe large vinyl sticker online
# 5196    uberlyfe large vinyl sticker best price free s...
# 5197                                      genuine product
# 5198                            day replacement guarantee
# Name: description, Length: 5199, dtype: object

# %%
from pipeline import tx_ml_preprocess
name = 'description'
sents, cla_labels = tx_ml_preprocess(name)
display(sents)
# Out:
# TEXT PREPROCESSING (DESCRIPTION)
# 0       key feature elegance polyester multicolor abst...
# 1       curtain enhances look curtain made high qualit...
# 2                      surreal attention sure steal heart
# 3       contemporary eyelet valance curtain slide smoo...
# 4       bring home elegant curtain softly filter light...
#                               ...
# 5194                            day replacement guarantee
# 5195              buy uberlyfe large vinyl sticker online
# 5196    uberlyfe large vinyl sticker best price free s...
# 5197                                      genuine product
# 5198                            day replacement guarantee
# Name: description, Length: 5199, dtype: object

# %%
from pipeline import *
name = 'description'

# TODO une seule fonction paramétrable par name + option de charger un résultat sauvegardé
# TODO : c'est ici que je devrais échantillonner. puis distinguer le fit et le transform
# TODO : fonctions paramétrables

sents, cla_labels = tx_ml_preprocess(name)
tx_ml_bow_count(sents, cla_labels, name)
tx_ml_bow_tfidf(sents, cla_labels, name)
tx_ml_word2vec(sents, cla_labels, name)
tx_ml_bert(sents, cla_labels, name)
tx_ml_use(sents, cla_labels, name)
# Out:
# TEXT PREPROCESSING (DESCRIPTION)
#
# BAG OF WORDS - COUNTVECTORIZER (DESCRIPTION)
#
# Feature extraction
#
# tSNE and ARI
# T-SNE time: 71.55s
# KMeans time: 0.80s
# ARI time: 0.01s
# Total time : 72.36s
#
# ARI : 0.0856
#
# Plot
# ARI :  0.08563313990066217
#
# BAG OF WORDS - TFIDFVECTORIZER (DESCRIPTION)
#
# Feature extraction
#
# tSNE and ARI
# T-SNE time: 67.98s
# KMeans time: 0.85s
# ARI time: 0.00s
# Total time : 68.83s
#
# ARI : 0.0348
#
# Plots
# ARI :  0.034775930646845074
#
# EMBEDDING - WORD2VEC (DESCRIPTION)
#
# Assemblage et entraînement du modèle
# ...

# %% [markdown]
# ## DEBUG USE

# %%
from tx_pipeline import tx_ml_preprocess, tx_ml_use
name = 'description'
sents, cla_labels = tx_ml_preprocess(name)
tx_ml_use(sents, cla_labels, name)
# Out:
# TEXT PREPROCESSING (DESCRIPTION)
#
# EMBEDDING - USE  (DESCRIPTION)
# Tensorflow version: 2.11.0
# Num GPUs Available: 0
# Built with cuda: False
#
# Feature extraction
# USE time: 13.11s
#
# tSNE and ARI
# T-SNE time: 59.44s
# KMeans time: 0.89s
# ARI time: 0.01s
# Total time : 60.34s
#
# ARI : 0.1115
#
# Plot
# ARI :  0.1114848413970803

# %% [markdown]
# # Finalisation
#
# On s'y remet. Voici le plan d'évolution de la pipeline :
# 1. On commence par le cas simple du Bag Of Word (cas Count et cas TfIdf)
# 2. On compare les résultats pour le corpus `product_name` et le corpus `description`.
# 2bis. On joue sur les paramètres possibles du vectorizer pour mesurer l'impact.
# 3. On ajoute la possibilité d'utiliser d'autres fonctions que tsne_kmeans_ari et on teste les 3 cas régression logistique multinomiale, arbres de décision et SVM multi-classes.
# 4. On ajoute une fonction pour sortir les mesures de performance et la représentation de la matrice de confusion.
# 5. On fait retourner à chaque fonction modifiée de pipeline.py le vecteur des cla_labels sous forme de matrice des probabilités n_sents x n_classes en vue de les exploiter en aval pour combiner les prédictions
# 6. tester méthodes avec kernel
# 7. entraîner le modèle avec l'un un échantillon stratifié des deux corpus et prédire à partir de lui même, à partir de l'autre corpus, et à partir de l'union des deux
